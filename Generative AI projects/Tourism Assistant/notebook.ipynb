# %% [markdown]
# ![eiffel-tower](images/eiffel-tower.png)
#
# Chat app for a virtual Parisian expert with OpenAI API, delivering valuable insights into the city's iconic landmarks and hidden treasures. The AI will respond intelligently to a set of common questions, providing a more engaging and immersive travel planning experience for the clientele of Peterman Reality Tours.
#
# The ultimate aspiration is a user-friendly, AI-driven travel guide that significantly enhances the exploration of Paris. Users will be able to pre-define their questions and receive well-informed answers from the AI, providing a seamless and intuitive travel planning process.

# %%
# Start your code here!
import os
from openai import OpenAI

# Define the model to use
model = "gpt-3.5-turbo"

# Define the client
client = OpenAI(api_key=os.environ["OPENAI"])
# Out:
# Running cells with 'Luis Marriott (Python 3.8.10)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Luis Marriott ipykernel --update-deps --force-reinstall'

# %%
conversation = [
    {'role': 'system',
    'content': "you are a virtual Parisian expert, delivering valuable insights into the city's iconic landmarks and hidden treasures"}
]

questions = ["How far away is the Louvre from the Eiffel Tower (in miles) if you are driving?", "Where is the Arc de Triomphe?","What are the must-see artworks at the Louvre Museum?"]

for q in questions:
    print("user:", q)
    message = {"role": "user", "content": q}
    conversation.append(message)
    response = client.chat.completions.create(
        model= "gpt-3.5-turbo",
        messages=conversation,  # Corrected 'message' to 'messages'
        temperature = 0,
        max_tokens=100  # Corrected 'tokens' to 'max_tokens'
    )
    assistant_dict = {"role": "assistant", "content": response.choices[0].message.content}
    conversation.append(assistant_dict)
    print("Assistant:", assistant_dict["content"])
# Out:
# user: How far away is the Louvre from the Eiffel Tower (in miles) if you are driving?
# Assistant: The Louvre Museum and the Eiffel Tower are approximately 2.5 miles apart if you are driving. The drive between these two iconic landmarks usually takes around 15-20 minutes, depending on traffic conditions.
# user: Where is the Arc de Triomphe?
# Assistant: The Arc de Triomphe is located at the western end of the Champs-Élysées avenue in the 8th arrondissement of Paris. It stands in the center of the Place Charles de Gaulle, also known as the Place de l'Étoile, from where 12 grand avenues radiate outwards, including the famous Avenue des Champs-Élysées. The Arc de Triomphe is a symbol of French national pride and a must-visit landmark in
# user: What are the must-see artworks at the Louvre Museum?
# Assistant: The Louvre Museum is home to an incredible collection of artworks spanning thousands of years. Some of the must-see artworks at the Louvre include:
#
# 1. "Mona Lisa" by Leonardo da Vinci - one of the most famous and iconic paintings in the world.
# 2. "Venus de Milo" - an ancient Greek statue of the goddess Aphrodite.
# 3. "Winged Victory of Samothrace" - a stunning Hellenistic sculpture of Nike, the Greek goddess of victory
